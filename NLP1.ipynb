# %% [markdown]
# <a href="https://colab.research.google.com/github/sourabhverma1302/AI-ML-Journey/blob/main/NLP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')

print("NLTK ready!")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# NLTK ready!

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

text = "I absolutely LOVED the restaurants in Perth!!! The food was amazing 😍 #Perth #foodie"

# Step 1 — Lowercase
text = text.lower()
print("Lowercase:", text)

# Step 2 — Remove special characters
text = re.sub(r'[^a-zA-Z\s]', '', text)
print("Cleaned:", text)

# Step 3 — Tokenise
tokens = word_tokenize(text)
print("Tokens:", tokens)

# Step 4 — Remove stopwords
stop_words = set(stopwords.words('english'))
tokens = [word for word in tokens if word not in stop_words]
print("No stopwords:", tokens)

# Step 5 — Lemmatization
lemmatizer = WordNetLemmatizer()
tokens = [lemmatizer.lemmatize(word) for word in tokens]
print("Lemmatized:", tokens)
# Out:
# Lowercase: i absolutely loved the restaurants in perth!!! the food was amazing 😍 #perth #foodie
# Cleaned: i absolutely loved the restaurants in perth the food was amazing  perth foodie
# Tokens: ['i', 'absolutely', 'loved', 'the', 'restaurants', 'in', 'perth', 'the', 'food', 'was', 'amazing', 'perth', 'foodie']
# No stopwords: ['absolutely', 'loved', 'restaurants', 'perth', 'food', 'amazing', 'perth', 'foodie']
# Lemmatized: ['absolutely', 'loved', 'restaurant', 'perth', 'food', 'amazing', 'perth', 'foodie']
